# %%
#!pip install -U spacy
#!pip install neuralcoref

# %%
# Import English model
import spacy
nlp = spacy.load("en_core_web_sm")
# load NeuralCoref and add it to the pipe of SpaCy's model
import neuralcoref
coref = neuralcoref.NeuralCoref(nlp.vocab)
nlp.add_pipe(coref, name='neuralcoref')
import pandas as pd
import numpy as np

# %%
# Read in data file
df = pd.read_csv('data.tsv', sep='\t')
df.head()
# Out:
#               ID                                               Text Pronoun  \
# 0  development-1  Zoe Telford -- played the police officer girlf...     her
# 1  development-2  He grew up in Evanston, Illinois the second ol...     His
# 2  development-3  He had been reelected to Congress, but resigne...     his
# 3  development-4  The current members of Crime have also perform...     his
# 4  development-5  Her Santa Fe Opera debut in 2005 was as Nuria ...     She
#
#    Pronoun-offset                  A  A-offset                B  B-offset  \
# 0             274     Cheryl Cassidy       191          Pauline       207
# 1             284          MacKenzie       228    Bernard Leach       251
# 2             265            Angeloz       173       De la Sota       246
# 3             321               Hell       174  Henry Rosenthal       336
# 4             437  Kitty Oppenheimer       219           Rivera       294
#
#                                                  URL
# 0  http://en.wikipedia.org/wiki/List_of_Teachers_...
# 1      http://en.wikipedia.org/wiki/Warren_MacKenzie
# 2  http://en.wikipedia.org/wiki/Jos%C3%A9_Manuel_...
# 3          http://en.wikipedia.org/wiki/Crime_(band)
# 4        http://en.wikipedia.org/wiki/Jessica_Rivera

# %%
# Create result dataframe to store mention offsets
spacy_resolved = pd.DataFrame()
spacy_resolved['ID'] = df['ID']
spacy_resolved['mention_offset'] = 0
spacy_resolved['mention'] = ''
spacy_resolved.head()
# Out:
#               ID  mention_offset mention
# 0  development-1               0
# 1  development-2               0
# 2  development-3               0
# 3  development-4               0
# 4  development-5               0

# %%
def fine_mention():

# %%
# Loop over the dataframe rows
def find_main(data):
    resolved = pd.DataFrame()
    for i in range(len(data)):
        index = data.loc[i, 'ID']
        doc = nlp(data.loc[i,"Text"])
        for token in doc:
            # if token offset matches pronoun offset
            if token.idx == data.loc[i,"Pronoun-offset"]:
                # if coreference is resolved then find the character offset of the mention
                if token._.coref_clusters != []:
                    resolved.loc[resolved['ID']==index, 'mention_offset'] = token._.coref_clusters[0].main.start_char
                    resolved.loc[resolved['ID']==index, 'mention'] = str(token._.coref_clusters[0].main)
                else:
                    resolved.loc[resolved['ID']==index, 'mention_offset'] = None
                    resolved.loc[resolved['ID']==index, 'mention'] = None
    return resolved

# %%
# Call function
f = find_main(df.loc[0:10,:], spacy_resolved)
f.dropna().head()
# Out:
#               ID mention_offset        mention
# 0  development-1            170  Phoebe Thomas
# 1  development-2              0             He
# 2  development-3             98     De la Sota
# 3  development-4            281           Rank
# 4  development-5              0            Her

# %%
resolved.set_index(resolved['ID'], inplace=True, drop=True)
resolved.drop(columns=['ID'], inplace=True)
resolved.drop(resolved.loc[resolved['mention_offset']=='X',:].index, axis=0, inplace=True)
resolved['mention_offset'] = resolved['mention_offset']
resolved.shape
# Out:
# (1806, 2)

# %%
#resolved.to_csv("spacy_resolved.csv")
resolved.head(10)
# Out:
#                mention_offset                                  mention
# ID
# development-1             170                            Phoebe Thomas
# development-2               0                                       He
# development-3              98                               De la Sota
# development-4             281                                     Rank
# development-5               0                                      Her
# development-6               0                           Sandra Collins
# development-7             152  Reb Asher's brother Rabbi Shlomo Arieli
# development-9             128                                     Mary
# development-10            196                       Christina Jennings
# development-12            217                                  Eleanor

# %%
# Correct answers
answers = pd.read_csv("submission.csv")    #Load submission file
answers['dummy'] = 'X'
answers['mention'] = df['A'] * answers['A'] + df['B'] * answers['B'] + answers['dummy'] * answers['NEITHER']
answers.set_index(answers['ID'], inplace=True)
answers.drop(columns=['ID', 'dummy'], inplace=True)
answers.drop(answers.loc[answers['mention']=='X',:].index, axis=0, inplace=True)
answers.head(10)
# Out:
#                 A  B  NEITHER             mention
# ID
# development-1   1  0        0      Cheryl Cassidy
# development-2   1  0        0           MacKenzie
# development-3   0  1        0          De la Sota
# development-4   0  1        0     Henry Rosenthal
# development-5   0  1        0              Rivera
# development-6   1  0        0             Collins
# development-8   0  1        0    Robert Christgau
# development-9   0  1        0              Kelsey
# development-10  1  0        0  Christina Jennings
# development-11  0  1        0         David Onley

# %%
join_answers_neuralcoref = pd.concat([answers['mention'], resolved['mention']], axis=1, join='inner')
join_answers_neuralcoref['similar'] = False
join_answers_neuralcoref.columns = ['answers', 'resolved', 'similar']
join_answers_neuralcoref.head(10)
# Out:
#                            answers            resolved  similar
# ID
# development-1       Cheryl Cassidy       Phoebe Thomas    False
# development-2            MacKenzie                  He    False
# development-3           De la Sota          De la Sota    False
# development-4      Henry Rosenthal                Rank    False
# development-5               Rivera                 Her    False
# development-6              Collins      Sandra Collins    False
# development-9               Kelsey                Mary    False
# development-10  Christina Jennings  Christina Jennings    False
# development-12             Eleanor             Eleanor    False
# development-13            Williams    Mary Helen Moses    False

# %%
# Answers that match with neuralcoref resolution results
for i in join_answers_neuralcoref.index:
    text1 = join_answers_neuralcoref.loc[i, 'answers']
    text2 = join_answers_neuralcoref.loc[i, 'resolved']
    if text1 == text2:
        join_answers_neuralcoref.loc[i, 'similar'] = True
    else:
        doc1 = set([word.text for word in nlp(text1)])
        doc2 = set([word.text for word in nlp(text2)])
        if len(doc1.intersection(doc2))>0:
            join_answers_neuralcoref.loc[i, 'similar'] = True
        else:
            join_answers_neuralcoref.loc[i, 'similar'] = False

# %%
join_answers_neuralcoref.head(20)
print(join_answers_neuralcoref['similar'].sum())
print(join_answers_neuralcoref.shape)
# Out:
# 833
# (1627, 3)

# %%
# CoreNLP resolved results
corenlp = pd.read_csv("core_nlp_resolved.csv")
corenlp.set_index(corenlp['ID'], inplace=True)
corenlp.drop(columns=['ID', 'Unnamed: 0'], inplace=True)
corenlp.head()
# Out:
#                       Resolution
# ID
# development-1      Phoebe Thomas
# development-2          MacKenzie
# development-3   Governor Angeloz
# development-5  Kitty Oppenheimer
# development-6     Sandra Collins

# %%
join_answers_corenlp = pd.concat([answers['mention'], corenlp['Resolution']], axis=1, join='inner')
join_answers_corenlp['similar'] = False
join_answers_corenlp.columns = ['answers', 'resolved', 'similar']
join_answers_corenlp.head(10)
# Out:
#                            answers  \
# ID
# development-1       Cheryl Cassidy
# development-2            MacKenzie
# development-3           De la Sota
# development-5               Rivera
# development-6              Collins
# development-8     Robert Christgau
# development-9               Kelsey
# development-10  Christina Jennings
# development-11         David Onley
# development-12             Eleanor
#
#                                                          resolved  similar
# ID
# development-1                                       Phoebe Thomas    False
# development-2                                           MacKenzie    False
# development-3                                    Governor Angeloz    False
# development-5                                   Kitty Oppenheimer    False
# development-6                                      Sandra Collins    False
# development-8   Greg Kot of the Chicago Tribune perceived `` f...    False
# development-9                                                Mary    False
# development-10                                 Christina Jennings    False
# development-11                                        David Onley    False
# development-12                                            Eleanor    False

# %%
# Answers that match with corenlp resolution results
for i in join_answers_corenlp.index:
    text1 = join_answers_corenlp.loc[i, 'answers']
    text2 = join_answers_corenlp.loc[i, 'resolved']
    if text1 == text2:
        join_answers_corenlp.loc[i, 'similar'] = True
    else:
        doc1 = set([word.text for word in nlp(text1)])
        doc2 = set([word.text for word in nlp(text2)])
        if len(doc1.intersection(doc2))>0:
            join_answers_corenlp.loc[i, 'similar'] = True
        else:
            join_answers_corenlp.loc[i, 'similar'] = False

# %%
join_answers_corenlp.head()
print(join_answers_corenlp['similar'].sum())
print(join_answers_corenlp.shape)
# Out:
# 879
# (1745, 3)

# %%
neural_corenlp = pd.concat([resolved['mention'], corenlp['Resolution']], axis=1, join='inner')
neural_corenlp['similar'] = False
neural_corenlp.columns = ['neuralcoref_resolved', 'corenlp_resolved', 'similar']
neural_corenlp.head(10)
# Out:
#                                    neuralcoref_resolved      corenlp_resolved  \
# ID
# development-1                             Phoebe Thomas         Phoebe Thomas
# development-2                                        He             MacKenzie
# development-3                                De la Sota      Governor Angeloz
# development-5                                       Her     Kitty Oppenheimer
# development-6                            Sandra Collins        Sandra Collins
# development-7   Reb Asher's brother Rabbi Shlomo Arieli  Reb Asher 's brother
# development-9                                      Mary                  Mary
# development-10                       Christina Jennings    Christina Jennings
# development-12                                  Eleanor               Eleanor
# development-13                         Mary Helen Moses      Mary Helen Moses
#
#                 similar
# ID
# development-1     False
# development-2     False
# development-3     False
# development-5     False
# development-6     False
# development-7     False
# development-9     False
# development-10    False
# development-12    False
# development-13    False

# %%
# Compare neuralcoref resolution with corenlp resolution
for i in neural_corenlp.index:
    text1 = neural_corenlp.loc[i, 'neuralcoref_resolved']
    text2 = neural_corenlp.loc[i, 'corenlp_resolved']
    if text1 == text2:
        neural_corenlp.loc[i, 'similar'] = True
    else:
        doc1 = set([word.text for word in nlp(text1)])
        doc2 = set([word.text for word in nlp(text2)])
        if len(doc1.intersection(doc2))>0:
            neural_corenlp.loc[i, 'similar'] = True
        else:
            neural_corenlp.loc[i, 'similar'] = False

# %%
print(neural_corenlp['similar'].sum())
print(neural_corenlp.shape)
# Out:
# 876
# (1764, 3)

# %%
neural_corenlp.head(10)
# Out:
#                                    neuralcoref_resolved      corenlp_resolved  \
# ID
# development-1                             Phoebe Thomas         Phoebe Thomas
# development-2                                        He             MacKenzie
# development-3                                De la Sota      Governor Angeloz
# development-5                                       Her     Kitty Oppenheimer
# development-6                            Sandra Collins        Sandra Collins
# development-7   Reb Asher's brother Rabbi Shlomo Arieli  Reb Asher 's brother
# development-9                                      Mary                  Mary
# development-10                       Christina Jennings    Christina Jennings
# development-12                                  Eleanor               Eleanor
# development-13                         Mary Helen Moses      Mary Helen Moses
#
#                 similar
# ID
# development-1      True
# development-2     False
# development-3     False
# development-5     False
# development-6      True
# development-7      True
# development-9      True
# development-10     True
# development-12     True
# development-13     True

# %%
# Out:
#                       Resolution
# ID
# development-1      Phoebe Thomas
# development-2          MacKenzie
# development-3   Governor Angeloz
# development-5  Kitty Oppenheimer
# development-6     Sandra Collins

# %%
# Answers that match with corenlp resolution results
for i in corenlp.index:
    text1 = corenlp.loc[i, 'Resolution']
    text2 = answers.loc[i, 'mention']
    if text1 == text2:
        answers.loc[i, 'corenlp_match'] = True
    else:
        doc1 = set([word.text for word in nlp(text1)])
        doc2 = set([word.text for word in nlp(text2)])
        if len(doc1.intersection(doc2))>0:
            answers.loc[i, 'corenlp_match'] = True
        else:
            answers.loc[i, 'corenlp_match'] = False
            
answers.head(20)
# Out:
#                 A  B  NEITHER             mention  neuralcoref_match  \
# ID
# development-1   1  0        0      Cheryl Cassidy              False
# development-2   1  0        0           MacKenzie              False
# development-3   0  1        0          De la Sota               True
# development-4   0  1        0     Henry Rosenthal              False
# development-5   0  1        0              Rivera              False
# development-6   1  0        0             Collins               True
# development-7   0  0        1                   X              False
# development-8   0  1        0    Robert Christgau              False
# development-9   0  1        0              Kelsey              False
# development-10  1  0        0  Christina Jennings               True
# development-11  0  1        0         David Onley              False
# development-12  1  0        0             Eleanor              False
# development-13  1  0        0            Williams              False
# development-14  1  0        0     Kazuki Nakajima               True
# development-15  1  0        0               Maria               True
# development-16  0  0        1                   X              False
# development-17  1  0        0             Maurice               True
# development-18  0  0        1                   X              False
# development-19  0  1        0                 Tim              False
# development-20  0  1        0              Ramsey               True
#
#                 corenlp_match
# ID
# development-1           False
# development-2            True
# development-3           False
# development-4           False
# development-5           False
# development-6            True
# development-7           False
# development-8           False
# development-9           False
# development-10           True
# development-11           True
# development-12           True
# development-13          False
# development-14           True
# development-15           True
# development-16          False
# development-17           True
# development-18          False
# development-19          False
# development-20           True

# %%
answers['neuralcoref_match'].sum()
# Out:
# 820

# %%
answers['corenlp_match'].sum()
# Out:
# 879

# %%
pd.concat([corenlp.loc[answers['corenlp_match']==True, 'Resolution'],answers.loc[answers['corenlp_match']==True,['mention', 'corenlp_match']]], axis=1)
# Out:
#                                                          Resolution  \
# ID
# development-2                                             MacKenzie
# development-6                                        Sandra Collins
# development-10                                   Christina Jennings
# development-11                                          David Onley
# development-12                                              Eleanor
# development-14                                      Kazuki Nakajima
# development-15                                      Maria 's mother
# development-17                                              Maurice
# development-20                                            Ramsey 's
# development-22                                                 Kurt
# development-23                                                Magee
# development-30                                                 Paul
# development-31                      Nicholas Rogers as Tarabas role
# development-35                          Bobby Peacock of Roughstock
# development-36                                          Cromwell 's
# development-39                                              Andreev
# development-45                           Felicity Dean 's Carol Ann
# development-54                                       Lorenzo Rubini
# development-55    A one-time student under Felix Weingartner and...
# development-58                                              Alleway
# development-59                                             Frank 's
# development-60                                              Lindsay
# development-70                                            Mauboy 's
# development-73                                               Pinter
# development-74                                                Doege
# development-76            Allmusic reviewer Stephen Thomas Erlewine
# development-78                    President Gloria Macapagal-Arroyo
# development-80                                             Petersen
# development-82    Philip who is declared commander of the League...
# development-87                                                Bongo
# ...                                                             ...
# development-1934                                     Mary Magdalene
# development-1935                                             Nellie
# development-1937                              history Phyllis Thede
# development-1940                                        Aisha Potty
# development-1943                                       Anjali Menon
# development-1944                                             Claire
# development-1945                         Ellen 's sister Julia Anne
# development-1948                                           Charlene
# development-1954                                             Joanne
# development-1958                                               Erin
# development-1960                                             Fey 's
# development-1961                                       Mrs , Waller
# development-1963                                             Stacey
# development-1964  Chelsea Hobbs -LRB- born Chelsea Raelle Hobbs ...
# development-1965                                       Karen Rolton
# development-1967                                            Matilda
# development-1969                                              Maria
# development-1973                                   Joanna Heffernan
# development-1974                                          Brooke 's
# development-1976  Madeline Hatter -LRB- voiced by Cindy Robinson...
# development-1977                                                Amy
# development-1978                                              Jacky
# development-1980                                             Haiduk
# development-1983                                   Mrs Edith Weston
# development-1985  Biddall 's former Hollyoaks cast-mate Zoe List...
# development-1989                                            Lily 's
# development-1990                                      Thea Musgrave
# development-1992                                               Lucy
# development-1993                                              Jenny
# development-1998                                              Maria
#
#                                   mention  corenlp_match
# ID
# development-2                   MacKenzie           True
# development-6                     Collins           True
# development-10         Christina Jennings           True
# development-11                David Onley           True
# development-12                    Eleanor           True
# development-14            Kazuki Nakajima           True
# development-15                      Maria           True
# development-17                    Maurice           True
# development-20                     Ramsey           True
# development-22                       Kurt           True
# development-23                      Magee           True
# development-30                       Paul           True
# development-31                     Rogers           True
# development-35              Bobby Peacock           True
# development-36                   Cromwell           True
# development-39                    Andreev           True
# development-45                  Carol Ann           True
# development-54             Lorenzo Rubini           True
# development-55                       Rees           True
# development-58                    Alleway           True
# development-59                      Frank           True
# development-60                    Lindsay           True
# development-70                     Mauboy           True
# development-73                     Pinter           True
# development-74                 Seth Doege           True
# development-76    Stephen Thomas Erlewine           True
# development-78    Gloria Macapagal-Arroyo           True
# development-80                   Petersen           True
# development-82                  Philip II           True
# development-87                      Bongo           True
# ...                                   ...            ...
# development-1934                Magdalene           True
# development-1935                   Nellie           True
# development-1937            Phyllis Thede           True
# development-1940              Aisha Potty           True
# development-1943             Anjali Menon           True
# development-1944                   Claire           True
# development-1945               Julia Anne           True
# development-1948                 Charlene           True
# development-1954                   Joanne           True
# development-1958                     Erin           True
# development-1960                      Fey           True
# development-1961                   Waller           True
# development-1963                   Stacey           True
# development-1964                    Hobbs           True
# development-1965             Karen Rolton           True
# development-1967                  Matilda           True
# development-1969                    Maria           True
# development-1973         Joanna Heffernan           True
# development-1974                   Brooke           True
# development-1976                   Maddie           True
# development-1977                      Amy           True
# development-1978                    Jacky           True
# development-1980                   Haiduk           True
# development-1983             Edith Weston           True
# development-1985                  Biddall           True
# development-1989                     Lily           True
# development-1990                 Musgrave           True
# development-1992                     Lucy           True
# development-1993                    Jenny           True
# development-1998                    Maria           True
#
# [879 rows x 3 columns]

# %%
(answers['A']+answers['B']+answers['NEITHER'] == 1).sum()
# Out:
# 2000

# %%
joined_mentions = pd.concat([corenlp['Resolution'], resolved['mention']], axis=1, join='inner')
joined_mentions['similar'] = False
joined_mentions.head()
# Out:
#                       Resolution         mention  similar
# ID
# development-1      Phoebe Thomas   Phoebe Thomas    False
# development-2          MacKenzie              He    False
# development-3   Governor Angeloz      De la Sota    False
# development-5  Kitty Oppenheimer             Her    False
# development-6     Sandra Collins  Sandra Collins    False

# %%
for i in joined_mentions.index:
    text1 = joined_mentions.loc[i, 'Resolution']
    text2 = joined_mentions.loc[i, 'mention']
    if text1 == text2:
        joined_mentions.loc[i, 'similar'] = True
    else:
        doc1 = set([word.text for word in nlp(text1)])
        doc2 = set([word.text for word in nlp(text2)])
        if len(doc1.intersection(doc2))>0:
            joined_mentions.loc[i, 'similar'] = True
        else:
            joined_mentions.loc[i, 'similar'] = False
            
joined_mentions.head(50)
# Out:
#                                                        Resolution  \
# ID
# development-1                                       Phoebe Thomas
# development-2                                           MacKenzie
# development-3                                    Governor Angeloz
# development-5                                   Kitty Oppenheimer
# development-6                                      Sandra Collins
# development-7                                Reb Asher 's brother
# development-8   Greg Kot of the Chicago Tribune perceived `` f...
# development-9                                                Mary
# development-10                                 Christina Jennings
# development-11                                        David Onley
#
#                                                 mention  similar
# ID
# development-1                             Phoebe Thomas     True
# development-2                                        He    False
# development-3                                De la Sota    False
# development-5                                       Her    False
# development-6                            Sandra Collins     True
# development-7   Reb Asher's brother Rabbi Shlomo Arieli     True
# development-8                                         X    False
# development-9                                      Mary     True
# development-10                       Christina Jennings     True
# development-11                                        X    False

# %%
joined_mentions['similar'].sum()
# Out:
# 863

# %%
answers.shape
# Out:
# (1799, 4)

# %%
None
