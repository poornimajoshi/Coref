# %%
# !pip install -U StanfordCoreNLP
# !pip install -U pycorenlp
# Out:
# Requirement already up-to-date: StanfordCoreNLP in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (3.9.1.1)
# Requirement not upgraded as not directly required: requests in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from StanfordCoreNLP) (2.18.4)
# Requirement not upgraded as not directly required: psutil in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from StanfordCoreNLP) (5.4.5)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from requests->StanfordCoreNLP) (3.0.4)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from requests->StanfordCoreNLP) (2.6)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from requests->StanfordCoreNLP) (1.22)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from requests->StanfordCoreNLP) (2019.3.9)
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already up-to-date: pycorenlp in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (0.3.0)
# Requirement not upgraded as not directly required: requests in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from pycorenlp) (2.18.4)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from requests->pycorenlp) (3.0.4)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from requests->pycorenlp) (2.6)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from requests->pycorenlp) (1.22)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /Users/poornimajoshi/anaconda3/lib/python3.6/site-packages (from requests->pycorenlp) (2019.3.9)
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Read in data file
import pandas as pd
data = pd.read_csv('data.tsv', sep='\t')
data.set_index(data.columns[0], inplace=True)

data.head(5)
# Out:
#                                                             Text Pronoun  \
# ID
# development-1  Zoe Telford -- played the police officer girlf...     her
# development-2  He grew up in Evanston, Illinois the second ol...     His
# development-3  He had been reelected to Congress, but resigne...     his
# development-4  The current members of Crime have also perform...     his
# development-5  Her Santa Fe Opera debut in 2005 was as Nuria ...     She
#
#                Pronoun-offset                  A  A-offset                B  \
# ID
# development-1             274     Cheryl Cassidy       191          Pauline
# development-2             284          MacKenzie       228    Bernard Leach
# development-3             265            Angeloz       173       De la Sota
# development-4             321               Hell       174  Henry Rosenthal
# development-5             437  Kitty Oppenheimer       219           Rivera
#
#                B-offset                                                URL
# ID
# development-1       207  http://en.wikipedia.org/wiki/List_of_Teachers_...
# development-2       251      http://en.wikipedia.org/wiki/Warren_MacKenzie
# development-3       246  http://en.wikipedia.org/wiki/Jos%C3%A9_Manuel_...
# development-4       336          http://en.wikipedia.org/wiki/Crime_(band)
# development-5       294        http://en.wikipedia.org/wiki/Jessica_Rivera

# %%
len(data)
# Out:
# 2000

# %%
data.isna().sum()
# Out:
# Text              0
# Pronoun           0
# Pronoun-offset    0
# A                 0
# A-offset          0
# B                 0
# B-offset          0
# URL               0
# dtype: int64

# %%
from pycorenlp import StanfordCoreNLP
import numpy as np

nlp = StanfordCoreNLP('http://localhost:9000')

resolved_lst = []
def resolve(corenlp_output, pronoun, index, develop_num):
    #print(corenlp_output)
    """ Transfer the word form of the antecedent to its associated pronominal anaphor(s) """
    for coref in corenlp_output['corefs']:
        mentions = corenlp_output['corefs'][coref]
        antecedent = mentions[0]  # the antecedent is the first mention in the coreference chain
        #print(antecedent)
        for j in range(1, len(mentions)):
            mention = mentions[j]
            target_sentence_original = mention['sentNum']
            target_token_original = mention['startIndex'] - 1
            offset_original_text = corenlp_output['sentences'][target_sentence_original - 1]['tokens'][target_token_original]
            
            if mention['text'] == pronoun and offset_original_text['characterOffsetBegin'] == index:
                #print("I am here for mention:",mention)
                #print("I am the pronoun", pronoun)
                
                # get the attributes of the target mention in the corresponding sentence
                target_sentence = mention['sentNum']
                target_token = mention['startIndex'] - 1
                # transfer the antecedent's word form to the appropriate token in the sentence
                #print("Here to see word:",corenlp_output['sentences'][target_sentence - 1]['tokens'][target_token]['word'])
                corenlp_output['sentences'][target_sentence - 1]['tokens'][target_token]['word'] = antecedent['text']
                
                #print("Checking :", corenlp_output['sentences'][target_sentence - 1]['tokens'][target_token])
                print("Resolved entity", antecedent)
                #cols = ['ID', 'A', 'B', 'NEITHER']
                #d = pd.DataFrame(0, index=np.arange(len(data)), columns=cols)
                #df.to_csv('out.csv')
                resolved_lst.append(develop_num + antecedent['text'])
                return resolved_lst


def print_resolved(corenlp_output):
    """ Print the "resolved" output """
    possessives = ['her', 'His', 'his', 'She', 'she', 'him', 'He', 'Her', 'he']
    for sentence in corenlp_output['sentences']:
        for token in sentence['tokens']:
            output_word = token['word']
            # check lemmas as well as tags for possessive pronouns in case of tagging errors
            if token['lemma'] in possessives or token['pos'] == 'PRP$':
                output_word += "'s"  # add the possessive morpheme
            output_word += token['after']
            print(output_word, end='')

# %%
for row in data.iterrows():
    #resolved_text = resolved_text.append([row[1]['Text']])
    output = nlp.annotate((row[1]['Text']), properties= {'annotators':'dcoref','outputFormat':'json','ner.useSUTime':'false'})
    #print(row[1][1], row[1][2])
    print(row[0])
    resolved_list = resolve(output, row[1][1], row[1][2], row[0])
    #print('Original:\n')
    #print((row[1]['Text']))
    #print('Resolved: \n')
    #print_resolved(output)
# Out:
# development-1
# Resolved entity {'id': 11, 'text': 'Phoebe Thomas', 'type': 'PROPER', 'number': 'SINGULAR', 'gender': 'FEMALE', 'animacy': 'ANIMATE', 'startIndex': 1, 'endIndex': 3, 'headIndex': 2, 'sentNum': 3, 'position': [3, 1], 'isRepresentativeMention': True}
# development-2
# Resolved entity {'id': 24, 'text': 'MacKenzie', 'type': 'PROPER', 'number': 'SINGULAR', 'gender': 'MALE', 'animacy': 'ANIMATE', 'startIndex': 1, 'endIndex': 2, 'headIndex': 1, 'sentNum': 3, 'position': [3, 1], 'isRepresentativeMention': True}
# development-3
# Resolved entity {'id': 14, 'text': 'Governor Angeloz', 'type': 'PROPER', 'number': 'SINGULAR', 'gender': 'MALE', 'animacy': 'ANIMATE', 'startIndex': 3, 'endIndex': 5, 'headIndex': 4, 'sentNum': 3, 'position': [3, 1], 'isRepresentativeMention': True}
# development-4
# development-5
# Resolved entity {'id': 14, 'text': 'Kitty Oppenheimer', 'type': 'PROPER', 'number': 'SINGULAR', 'gender': 'FEMALE', 'animacy': 'ANIMATE', 'startIndex': 12, 'endIndex': 14, 'headIndex': 13, 'sentNum': 3, 'position': [3, 5], 'isRepresentativeMention': True}
# development-6
# Resolved entity {'id': 1, 'text': 'Sandra Collins', 'type': 'PROPER', 'number': 'SINGULAR', 'gender': 'FEMALE', 'animacy': 'ANIMATE', 'startIndex': 1, 'endIndex': 3, 'headIndex': 2, 'sentNum': 1, 'position': [1, 1], 'isRepresentativeMention': True}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a1bc8d4aeab3> in <module>()
#       2 for row in data.iterrows():
#       3     #resolved_text = resolved_text.append([row[1]['Text']])
# ----> 4     output = nlp.annotate((row[1]['Text']), properties= {'annotators':'dcoref','outputFormat':'json','ner.useSUTime':'false'})
#       5     #print(row[1][1], row[1][2])
#       6     print(row[0])
#
# ~/anaconda3/lib/python3.6/site-packages/pycorenlp/corenlp.py in annotate(self, text, properties)
#      27             self.server_url, params={
#      28                 'properties': str(properties)
# ---> 29             }, data=data, headers={'Connection': 'close'})
#      30         output = r.text
#      31         if ('outputFormat' in properties
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#lst = set(resolved_list)

# %%
len(resolved_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-4382f2266792> in <module>()
# ----> 1 len(resolved_list)
#
# NameError: name 'resolved_list' is not defined

# %%
resolved_list
# Out:
# ['development-1Phoebe Thomas',
#  'development-2MacKenzie',
#  'development-3Governor Angeloz',
#  'development-5Kitty Oppenheimer',
#  'development-6Sandra Collins',
#  "development-7Reb Asher 's brother",
#  "development-8Greg Kot of the Chicago Tribune perceived `` formula production and hack songwriting '' , but complimented Pink 's personality and its `` handful '' of worthy tracks .",
#  'development-9Mary',
#  'development-10Christina Jennings',
#  'development-11David Onley',
#  'development-12Eleanor',
#  'development-13Mary Helen Moses',
#  'development-14Kazuki Nakajima',
#  "development-15Maria 's mother",
#  'development-16McCulloch',
#  'development-17Maurice',
#  'development-18his',
#  'development-19Justin at the Beatdown',
#  "development-20Ramsey 's",
#  'development-21Mike Stewart for more than 15 years',
#  'development-22Kurt',
#  'development-23Magee',
#  'development-24Maggie Anderson',
#  'development-25Margaret Bell',
#  'development-26Michael Billington in The Guardian',
#  'development-27Beth',
#  'development-28The victim',
#  'development-29MMA fighter Eddie Alvarez with a record of 22 wins and 2 losses',
#  'development-30Paul',
#  'development-31Nicholas Rogers as Tarabas role',
#  'development-32the Black Witch',
#  'development-33Elsie and Steve Tanner on their wedding day',
#  'development-34she',
#  'development-35Bobby Peacock of Roughstock',
#  "development-36Cromwell 's",
#  'development-37his brother Cornelis',
#  'development-38Roberta Reid',
#  'development-39Andreev',
#  'development-40a Democrat',
#  'development-41Karl Philipp',
#  'development-42the Conservatives',
#  "development-43's",
#  'development-44Paola',
#  "development-45Felicity Dean 's Carol Ann",
#  'development-47her grandmother',
#  'development-48a conservative lesbian African American',
#  'development-49his 2nd wife',
#  'development-50Rusty Magee to a libretto',
#  'development-51a',
#  'development-52Dr. Carly Manning',
#  'development-53her',
#  'development-54Lorenzo Rubini',
#  'development-55A one-time student under Felix Weingartner and former violinist with the Hall * , Rees',
#  'development-56the May Frere at port of Bhavnagar , Colonel Barton -LRB- the political Agent -RRB-',
#  'development-57director Sophie Consagra',
#  'development-58Alleway',
#  "development-59Frank 's",
#  'development-60Lindsay',
#  'development-61Matthew 12:40 , 27:63',
#  'development-62bad-girl Naomi Clark',
#  'development-63Future-President George W. Bush',
#  'development-64current world champion Lu Lan of China',
#  'development-65Glabius',
#  'development-66the writer',
#  'development-67the mother of Peter',
#  'development-68Rathnavel -LRB- R. P. Viswam -RRB-',
#  'development-69his wife',
#  "development-70Mauboy 's",
#  'development-71Robert Flaherty',
#  'development-72Cosima Liszt',
#  'development-73Pinter',
#  'development-74Doege',
#  'development-75Sir Ralph Abercromby',
#  'development-76Allmusic reviewer Stephen Thomas Erlewine',
#  'development-77Samtown',
#  'development-78President Gloria Macapagal-Arroyo',
#  'development-79Hermann Grassmann -LRB- advancing the use of vector analysis -RRB-',
#  'development-80Petersen',
#  'development-81a baby girl',
#  "development-82Philip who is declared commander of the League 's army",
#  'development-83his wife',
#  'development-84a minister',
#  'development-85Daisy',
#  'development-87Bongo',
#  'development-88Daniel',
#  'development-89Alphonse Royer',
#  "development-90Elizabeth 's",
#  "development-91Donald MacArthur -LRB- the ` Occasional ' -RRB-",
#  'development-92his daughter',
#  'development-93Bonnie Grabenhofer of Illinois',
#  "development-94Alice 's",
#  'development-95Charlie Weis',
#  'development-96George Caswell',
#  "development-97Tredway 's",
#  'development-98Margrave Leopold III of Austria',
#  'development-99Jacques',
#  'development-100a protege of Bounty Killer',
#  'development-101Re-elected in the 2007 election',
#  'development-102a strip club owner',
#  'development-103Donald P. Kanak',
#  'development-104His',
#  'development-105Eliza Simmons Bryant -LRB- 1827 -- May 13 , 1907 -RRB-',
#  'development-106Julia',
#  'development-107Asha',
#  'development-108the Americans',
#  'development-109Tami Lynne',
#  'development-110Charles Cawley',
#  'development-111Alice Perrers',
#  'development-112Danny Goldman',
#  'development-113Another homeroom teacher',
#  'development-114Gallant Lord Flashheart',
#  'development-115almost Angelica',
#  'development-116Elsie',
#  'development-117Yang Xiong',
#  'development-118Anna Brewster',
#  'development-119secretary general of the party',
#  'development-120Oliveira',
#  'development-121Hudd',
#  'development-122author and National Book Award Winner for The Feast of Love Leo J. Enright',
#  'development-123Unbeknownst to them',
#  'development-124King of Delhi , King Feroz Shah Tughlaq',
#  'development-125Donald Deacon',
#  'development-126Massachusetts Governor Charlie Baker in 2014',
#  'development-127Brian Wilson',
#  'development-128Smith',
#  'development-129Haritha',
#  'development-130Carney',
#  'development-131Jerry Marshall',
#  'development-132he',
#  'development-133Jones',
#  'development-134The couple',
#  'development-135The leader of the Legnano -- Pirelli team , Graziano Battistini',
#  'development-136Miller',
#  'development-137The 20-year-old Nyro',
#  'development-138Hayes',
#  'development-139DeLaurentis/Carolco -LRB- now EUE Screen Gems -RRB-',
#  "development-140Catherine Falconetti -LRB- Ullman -RRB- to local butcher Joseph Santangelo -LRB- D'Onofrio -RRB-",
#  'development-141Isabel',
#  'development-142Isabel',
#  'development-143Yukiko Shinozaki',
#  "development-144Diane 's granddaughter Charlotte de la Marck , the ch",
#  'development-145Rocky',
#  'development-146Natasha',
#  'development-147Edward Monro',
#  'development-148The actress Dian Sastrowardoyo',
#  "development-149Bieber 's",
#  'development-150even Siva from ` The Wanted',
#  'development-151Colonel Palmer',
#  'development-152Mary Moore',
#  'development-153The poor',
#  'development-154Gloria over Rita',
#  "development-155Woman 's",
#  'development-156Alexander the Great -LRB- 356BC-323BC -RRB-',
#  'development-157Liszt',
#  'development-158Bennett',
#  'development-159Deacon',
#  'development-160Henrietta Anne Hoare',
#  "development-161Lindsay Lohan 's",
#  "development-162his father 's",
#  "development-163Riotta 's",
#  'development-164Quinn',
#  'development-165Ardon Benjamin Holcomb -LRB- Born June 23 , 1804 in North Granby , Hartford , Connecticut ; died September 29 , 1879 -RRB- , a lawyer',
#  'development-166Noah for future occupation',
#  'development-167Geller',
#  "development-168Noble `` Thin Man '' Watts -LRB- February 17 , 1926 -- August 28 , 2004 -RRB-",
#  'development-169some',
#  'development-170an educationist',
#  'development-171The Mark Twain book A Tramp',
#  'development-172his new master',
#  'development-173Murray',
#  'development-174Sarah Wigglesworth',
#  'development-175Sherwood',
#  "development-176Fred 's cellmate",
#  'development-177Aleksey Mikhailovich',
#  'development-178contender Oba Carr in February 1999',
#  'development-179She',
#  'development-180Johnny Dee',
#  'development-181Yuan Sijun -LRB- born 29 May 2000 in Fujian -RRB-',
#  'development-182Pavlik',
#  'development-183The Red Rose of Lancaster',
#  'development-184Susan Mtegha',
#  'development-185Kelsey',
#  "development-187Harold Fleming 's `` splendid left-foot shot ''",
#  'development-188the bartender Horace trapped under debris',
#  'development-189Edith',
#  "development-190Ceruti 's",
#  'development-191Tad Gruzsa',
#  'development-192Aguilar',
#  'development-193Miss Palmer',
#  'development-194Julie Madison',
#  'development-195Lady Thiang',
#  "development-196Honda 's 350th Grand Prix as an engine supplier and the first time",
#  'development-197Lee',
#  "development-198Verdi 's Don Carlos",
#  'development-199Belle',
#  'development-200Belle',
#  'development-201He',
#  'development-202Artigas , who thought that the gauchos were not treated well',
#  'development-203Groucutt',
#  'development-204Quincy Jones',
#  'development-205her old boyfriend',
#  'development-206Blige',
#  'development-207Petter',
#  'development-208Victoria',
#  'development-209Giggs',
#  'development-210Barlow',
#  "development-211Margaret Thatcher 's",
#  'development-212Ricardo',
#  "development-213Teri Ann Linn that Kristen was no longer needed in the show 's current storylines",
#  'development-214Mickey Holliday',
#  "development-215Isabelle 's",
#  'development-216Heidi',
#  'development-217George H. Throop',
#  'development-219Toshney',
#  'development-220Byas',
#  'development-221a member of the Western Australian Legislative Council',
#  'development-222Rubenfeld',
#  'development-223Vivian',
#  'development-224Dunstan',
#  'development-225John Nixon -LRB- May 10 , 1815 - June 3 , 1899 -RRB- , English mining engineer and colliery proprietor',
#  "development-226Assistant to First Lady Hillary Rodham Clinton 's Chief of Staff",
#  'development-227Tracey Chapman',
#  'development-228Bonnie Tyler -LRB- then known as Gaynor Hopkins -RRB-',
#  'development-229Stephanie Merritt of',
#  'development-230Jean Baptiste Boisot',
#  'development-231her',
#  'development-232Father Joseph',
#  'development-233Elizabeth Frances Zane in Chicago , Illinois',
#  'development-234He',
#  "development-235Sarah 's aunt Emily Eden",
#  'development-236Isabel',
#  'development-237Isabel',
#  'development-238Richard',
#  'development-239Crummell',
#  'development-240his father Emperor Kang',
#  'development-241Yana',
#  'development-242The victim',
#  'development-243a guest vocalist',
#  'development-244Grace Lumpkin',
#  'development-245Sasha',
#  "development-246Hubbell 's overbearing mother",
#  'development-247Yi ` nan',
#  "development-248music journalist Daniel Cooper 's",
#  'development-249Lee Roy Martin',
#  'development-250Conrad',
#  'development-251Troy',
#  'development-252Rita Verdonk',
#  'development-253Celia',
#  'development-254Emma',
#  'development-255Robin',
#  'development-256the character of Mary , who suffers from a mental illness',
#  'development-257James Syme',
#  'development-258Herbert',
#  'development-259Malcolm Rifkind',
#  'development-260Dyer then race',
#  'development-261Smith',
#  'development-262Eric Matisoff',
#  "development-263Bordo 's",
#  'development-264Abram',
#  'development-265Giovanna Pessi',
#  'development-266Conlan',
#  'development-268his friend Blaise -LRB- Kotto -RRB-',
#  'development-269She',
#  'development-270Emma',
#  'development-271Pratap',
#  'development-272The top guard in the SEC',
#  'development-273William',
#  'development-274Busch still leading',
#  'development-275Lisa',
#  'development-276Lisa',
#  'development-277Bart',
#  'development-278some',
#  'development-279Rinker',
#  'development-280Gao Jixing',
#  'development-281Eleanor',
#  'development-282Kieran Richardson',
#  'development-283Bissett',
#  'development-284Arthur W. Saha',
#  'development-285compatriot Vasek Pospisil',
#  'development-286Dr. John P. Brookins',
#  'development-287Uncle Petrie',
#  'development-288Her',
#  'development-289Kudryavtseva',
#  'development-290Corby',
#  'development-291Llewellyn',
#  'development-292Melinda',
#  'development-293Sylvia Plath',
#  'development-294the debuting Jayme Jameson',
#  'development-295Dante',
#  'development-296Villefort',
#  'development-297John Wayne from 1926 to 1976 , which also includes those films that Wayne only produced , and results pertaining to his long-running box office popularity between 1949 and 1973',
#  'development-298Ramanand Sagar',
#  'development-299Granell',
#  'development-300William Stewart',
#  'development-301Kevin Keegan',
#  "development-302Sarah 's",
#  'development-303Stanner',
#  'development-304Addams',
#  'development-305Neither character',
#  'development-306Wally Backman and Keith Hernandez',
#  'development-307Vettel',
#  'development-308Special Agent',
#  'development-309Alexander Irvin',
#  'development-310A.J. Styles',
#  'development-311Janet',
#  'development-312Harriet',
#  'development-313Stephanie',
#  'development-314Roman Steinberg -LRB- April 5 , 1900 -- April 16 , 1928 -RRB- from Tallinn , Estonia',
#  'development-315Maria',
#  'development-316Stevens',
#  'development-317Marenghi',
#  'development-318Lillian Cleaves',
#  'development-319Lindrum',
#  'development-320Caressa',
#  'development-321Pancho Villa in 1916',
#  'development-322Niall',
#  "development-323Tewodros II 's",
#  'development-324a malevolent ghost',
#  'development-325Robert',
#  'development-326Hillary Clinton',
#  'development-327Prof. Larsson',
#  'development-328Portia',
#  "development-329his father 's",
#  'development-330Mermet',
#  'development-331Vivian who is entombed , and after escaping',
#  'development-332Victor',
#  'development-333his father',
#  'development-334Princess Margaret in the upcoming film',
#  'development-335Bree',
#  'development-336Gabrielle',
#  'development-337Sam Allen',
#  'development-338Millar',
#  'development-339Ibn Thabit',
#  'development-340Rusedski',
#  'development-341Jean',
#  "development-342Heather O'Rourke -LRB- December 27 , 1975 -- February 1 , 1988 -RRB-",
#  'development-343Sharon Rich',
#  'development-344Chueathai',
#  'development-345Caepio',
#  'development-346Ryan',
#  'development-347The character of Gerard',
#  'development-348Krystal Carey',
#  "development-349Alexander Haig 's",
#  'development-350Brentford manager Harry Curtis',
#  'development-351Jo',
#  'development-352Rachel',
#  'development-35316-year-old Elizabeth Pe',
#  'development-354James',
#  'development-355Percy',
#  'development-356Frank',
#  'development-357Joe',
#  "development-358Connor 's mother",
#  'development-360Harris',
#  'development-361Kira Nerys',
#  'development-362Patricia',
#  'development-363Steingut',
#  'development-364Sarah Fitz-Gerald',
#  'development-365Jon Lee Anderson',
#  'development-366Evangeline',
#  'development-367Howard',
#  'development-368Brian Grazer',
#  'development-369Gandhian',
#  'development-370each',
#  'development-371Christy -LRB- released in 1967 -RRB-',
#  'development-372Catherine Marshall',
#  "development-373Jake Vargas as Jepoy -LRB- Guitar Enthusiast -RRB- - the group 's resident rocker .",
#  'development-374Harbutt',
#  "development-375Yuka 's corpse",
#  'development-376the Queen',
#  'development-377John Paulet',
#  'development-378Temerlin',
#  "development-379alway on King 's integrity",
#  'development-380Constantius',
#  'development-381Justin Tranter',
#  'development-382Johan Bj',
#  'development-383Ian Parkin -LRB- born Wakefield , Yorkshire , 1950 - 1 July 1995 -RRB-',
#  'development-384Joe Morgan',
#  'development-385a literary mentor',
#  'development-386Steve Blizzard',
#  'development-387Basu',
#  'development-388Cousin Helen',
#  'development-389the oldest of four children of Earl Andrew Forsythe , an attorney , and Janet Kendall Forsythe',
#  'development-390Traci Peterson',
#  "development-392Moore 's",
#  'development-393She',
#  'development-394Lisa Brock',
#  'development-395Don',
#  'development-396Robles',
#  'development-397Queen Eleanor',
#  'development-399Adam',
#  'development-400Wolman',
#  "development-402Me ''",
#  'development-403she',
#  'development-404Etta -LRB- voiced by Leigh-Allyn Baker -RRB-',
#  'development-405Anya',
#  'development-406fourth member Barbara Martin',
#  'development-407Venetists',
#  'development-408Frutkin',
#  'development-409Deanna in various costumes dressed as Madonna',
#  'development-410Lisa Hunter',
#  'development-411Faida Hamdy',
#  'development-412Fern Britton',
#  'development-413Boswell himself',
#  "development-414Tilly 's",
#  'development-415Williamite',
#  'development-416Rufus',
#  'development-417Governor Kathleen Sebelius',
#  'development-418Alice',
#  'development-419Jeremy Gifford',
#  'development-420McClusky',
#  'development-421Robinson',
#  'development-422Thoms',
#  "development-423Ellison 's",
#  'development-424George',
#  'development-425David Hopkins , released in December 2010',
#  'development-426Dotty',
#  'development-427The couple',
#  'development-428Williams',
#  'development-429his father Ervin Robinson',
#  'development-430The actress',
#  'development-431Smith',
#  'development-43210th',
#  'development-433Jean-Gabriel De Tarde',
#  'development-434Pan American',
#  'development-435Mr. Kwan',
#  "development-436Cecilia 's",
#  'development-437Finn',
#  'development-438William P. Rogers',
#  'development-439David',
#  'development-440Christ',
#  "development-441Tony Bennett who was signed by Mitch Miller to Columbia Records on the strength of Bennett 's 1949 demo of the song",
#  'development-442Nicky Romero',
#  'development-443Heidi Roizen',
#  'development-444Theresa',
#  'development-445Gaiman',
#  'development-446Damian Woetzel',
#  'development-447Thomas',
#  'development-448Whilst Ali was preaching , a chief requested Salih to judge the message brought by Ali .',
#  'development-449Nazi',
#  'development-450her',
#  "development-451Raymond 's wife",
#  'development-452mother of two small children',
#  'development-453Maurice Renand',
#  'development-454Barbara Berman',
#  'development-455Barbara Berman',
#  'development-456consul candidate Marcus Cicero',
#  "development-457Dan Brown 's",
#  'development-458the philosopher',
#  'development-459Carlo Pedretti -LRB- born in Bologna , 1928 -RRB-',
#  'development-460Katniss',
#  'development-461those to pay tribute to the more famous of the two brothers',
#  'development-462Alice',
#  "development-463Penny 's other daughter Alice Sycamore",
#  "development-465Briana Scurry 's save of China 's third kick",
#  'development-466Henry Czerny',
#  'development-467Pius II',
#  'development-468an ex-Krimzon Guard of high authority',
#  'development-469Richard Davidson',
#  'development-470Louise',
#  'development-471Polly',
#  'development-472Wendi Richter',
#  'development-473WrestleReunion in an eight-woman tag team match -LRB- teaming with Bambi , Malia Hosaka',
#  'development-474Louisiana Governor Chip Majors -LRB- James DuMont -RRB-',
#  'development-475he',
#  'development-476a 24-hour guard',
#  'development-477The Swiss film critic Norbert Creutz',
#  'development-478the Catalan commander Roger de Flor',
#  "development-479William Wadsworth 's",
#  'development-480Her',
#  'development-481general manager Bobby Clarke',
#  'development-482Jones',
#  'development-483Mr. Bonjawo',
#  'development-484Zhang Feng',
#  'development-4852nd',
#  'development-486Blige',
#  'development-487He',
#  'development-488Robert de Montesquiou',
#  'development-489Suzanne',
#  'development-490she',
#  'development-491Martha',
#  'development-492Only Cardinal Benedetto Odescalchi',
#  'development-493Betty about her crush on Henry , calling him her `` Nerd Lover',
#  'development-494Baljeet',
#  'development-495her',
#  'development-496Faustina',
#  'development-497Ward',
#  'development-498the current Minister of Foreign Affairs of Abkhazia',
#  'development-499Gessle',
#  'development-500John Hoskyns',
#  'development-502Ernest Clark',
#  'development-503Pierre Caziot',
#  'development-504Catherine',
#  'development-505He',
#  'development-506to be nominated twice more , winning for a third time , this time in the category of Best Supporting Actress',
#  'development-507Jackson',
#  'development-508Ludmila Savinkova',
#  'development-509Jonah Anguka',
#  'development-510Sparkhouse -LRB- Red Production Company / BBC 2002 -RRB- ;',
#  'development-511Julie Marie Berman',
#  'development-512Lauren Mitchell',
#  'development-513Doyen',
#  'development-514the Apartheid-set drama Agaat',
#  'development-515Jared',
#  'development-516The cousin of Tigers outfielder Ron LeFlore , Steverson',
#  "development-517Betty 's family",
#  "development-518the band 's producer",
#  'development-519Eunice',
#  'development-520Jacques Villeneuve',
#  'development-521Brent Smith in 2001',
#  'development-522Sam Dryden',
#  'development-523Jay-Z',
#  'development-524Brendon Hartley',
#  'development-525documentarian Steve Zissou -LRB- Bill Murray -RRB-',
#  'development-526Bruton',
#  'development-527Lyricist Betty Thatcher-Newsinger',
#  'development-528Cynthia',
#  'development-529her celebrity',
#  'development-530Muir',
#  'development-531Moore',
#  'development-532her',
#  'development-533Paul Devereaux III',
#  'development-534McLean',
#  'development-535He',
#  'development-536Ed Fishman',
#  'development-537Ralph Vaughan Williams',
#  'development-538Jervis',
#  'development-539Luc Urbain de Bouexic',
#  "development-540Anand 's",
#  'development-541Nanci Griffith',
#  'development-542JESS3',
#  'development-543Wanda Ileen Barzee',
#  'development-544Elizabeth',
#  'development-545Welner with introducing significant new evidence into the case in his 206-page report .',
#  'development-546Helen Modern -LRB- born 16 February 1983 -RRB-',
#  'development-547Audrey',
#  "development-548the director of Larry 's Hollywood film",
#  'development-549Shumlin',
#  'development-550Hilda Satt',
#  "development-551Mary 's mother",
#  'development-552Baynes',
#  'development-553actress Glenn Close in the role',
#  'development-554the scruffy kid',
#  'development-555the architect',
#  'development-556Rosa Mendes',
#  'development-557Gardiner',
#  'development-558he',
#  'development-559Dave Navarro and Stephen Perkins',
#  'development-560Brian Alexander Morgan',
#  'development-561American mycologist William Murrill',
#  'development-562Chorney',
#  'development-563Marlene Palumbo from Indienink Music',
#  'development-564Knyvet',
#  'development-565Beyonc',
#  'development-566Bjorn',
#  'development-567his',
#  'development-568Eyre',
#  'development-569Justin Williams',
#  'development-570Roberts',
#  "development-571Benton 's father",
#  'development-572Benton',
#  'development-573Napoleon',
#  'development-574He',
#  'development-575Porter',
#  'development-576****',
#  'development-577Arianda',
#  "development-579Alf and Else 's",
#  "development-581someone named Ervin would write about Robert E. Howard 's Steve Costigan character from Fight Stories",
#  'development-582Margaret Cavendish',
#  'development-583His',
#  'development-584Brenda',
#  'development-585daughter of last witness',
#  'development-586Samuel',
#  'development-587Leadbetter',
#  'development-588Roy Ascott at Ealing Art College in West London between 1963 and 1966',
#  'development-589Clark',
#  "development-590Henry 's wife",
#  'development-591Moore',
#  'development-592Lulu Dark',
#  'development-593His father',
#  'development-594Jeff',
#  'development-595Stuart Robert',
#  'development-596Barkha',
#  'development-597Barkha',
#  'development-598Murasaki',
#  "development-599`` Mary Ann Bighead '' -- a mockery of the former Times columnist and assistant editor Mary Ann Sieghart .",
#  'development-600Anna Karenina',
#  'development-601Davis',
#  'development-602Graham',
#  'development-603the telepathy-immune Plastic Man',
#  'development-604a cricketer',
#  'development-605Cabinet Expertise Drouart',
#  'development-606an eight-woman Battle Royal',
#  'development-607Tom Tobin',
#  'development-608Liz Watts of Porchlight Films',
#  "development-609von Frisch 's",
#  'development-610Vald * tejn acquired Bukovina from Karel Kapoun from Svojkov .',
#  'development-611Martin',
#  'development-612Kevin Park -LRB- born September 2 , 1964 in Hythe , Alberta -RRB-',
#  "development-613George Hayes -LRB- later to become known as `` Gabby '' Hayes -RRB-",
#  'development-614Hebblethwaite',
#  'development-615Arnim Zola',
#  'development-616William',
#  'development-617Adam',
#  'development-618Giselle',
#  'development-619Pierre Gaisseau',
#  'development-620the City medical examiner',
#  'development-621Whitman as a defendant',
#  'development-622Wheatley',
#  'development-623Payne',
#  'development-624Many of the leaders',
#  'development-625Michael Cohl',
#  'development-626he',
#  'development-627Max',
#  'development-628A courtier as well as a soldier , Colonel Finch',
#  'development-629Woolf',
#  'development-630Len Righi of The Morning Call',
#  'development-631Thomas Hermanns -LRB- b. 5 March 1963 -RRB-',
#  'development-632Gentile Chris',
#  'development-633his now',
#  "development-634Jalousie ''",
#  'development-635Emicho of Leiningen',
#  'development-636Laura Michelle Kelly',
#  'development-637New York Mayor Michael Bloomberg',
#  'development-638She',
#  'development-639Lord Darwen',
#  'development-640Pat Magnum',
#  'development-641James Wolfe',
#  'development-642Sinclair',
#  "development-643Rossetti 's mother",
#  'development-644Roy Ward as Reverend Lucas Greene , the local Anglican priest .',
#  'development-645Patricia for a few years',
#  'development-646Irene',
#  'development-647Taylor',
#  'development-648John',
#  'development-649her daughter',
#  'development-650Riley',
#  'development-651her cousin in reality',
#  'development-652Alison Krauss',
#  'development-653Alison Krauss',
#  'development-654Ann',
#  'development-655Mary Freudstein',
#  'development-656Johan van Dorth -LRB- Horst , 1586 - Salvador , 17 July 1624 -RRB- , Lord of Horst and Pesch',
#  'development-657Angelina Beloff at the time',
#  'development-658Amy Winthrop',
#  'development-659Vedism',
#  "development-660Maureen 's",
#  'development-661Patricia',
#  'development-662Colette',
#  "development-663a scholar 's",
#  'development-664Madeleine',
#  'development-665Janet',
#  'development-666Nathan',
#  'development-667He',
#  'development-668The family',
#  'development-669Newton',
#  'development-670Jon Krakauer',
#  'development-671Kruse',
#  'development-672the Premiership Whitehead',
#  'development-673Katie Blair from Billings , Montana',
#  'development-674Clinton , Collier',
#  'development-675Sevyn',
#  'development-676Mac Akasaka',
#  'development-678Steve Brule : co-host of Engine Masters .',
#  'development-679Arsenault',
#  'development-680He',
#  'development-681Ramya Krishnan',
#  'development-682the daughter of civil engineer Colin McGregor Ure and Edith Swinburne',
#  'development-683the daughter of civil engineer Colin McGregor Ure and Edith Swinburne',
#  "development-684Leeds ' brother",
#  'development-685Godfrey',
#  'development-686Paduh',
#  'development-687Millar',
#  'development-688Bheem',
#  'development-689he',
#  'development-690Forbes',
#  'development-691Betanzos',
#  'development-692Ethan',
#  'development-693Fincher',
#  'development-694Wiggins',
#  'development-695Jews who escaped from Nazi persecution',
#  'development-696Gandhi',
#  'development-698Ruscha',
#  'development-699Layla Sarakalo',
#  'development-700she',
#  'development-701a rookie',
#  "development-702Cosima 's",
#  "development-703Clay 's",
#  'development-704Marco Vespucci',
#  'development-705Simonetta',
#  'development-706Sarah Armantrout',
#  'development-707You',
#  'development-708Ray Lindwall',
#  'development-709Emma Evans',
#  'development-711Halberstam',
#  'development-712He',
#  'development-713former Governor Sarah Palin of Alaska , the 2008 Republican vice-presidential nominee',
#  'development-714Lance',
#  "development-715Stephanie 's",
#  'development-716Tim',
#  'development-717G.K. Moopanar -LRB- ; 1931-2001 -RRB-',
#  'development-718James I',
#  'development-719Angela , who in turn is infatuated with Army surgeon Major Hilary Jarret',
#  'development-720Peggy Ryan',
#  'development-721Kartik Chandra Pal',
#  'development-722Flanagan',
#  'development-723Marco Pannella',
#  'development-724Frans Schwartz',
#  "development-725Tim Boswell 's",
#  'development-726Brown University professor Andries van Dam',
#  'development-727Seles',
#  'development-728Kate Flannery',
#  'development-729Kelly',
#  'development-730Andy McBride -LRB- Robert Paige -RRB-',
#  'development-731Andy Spade',
#  'development-732a member of the group',
#  'development-733co-written by Christos Gage and Mike Costa and drawn by Antonio Fuso',
#  "development-734Tachibana -LRB- ** -RRB- Rito 's junior from his middleschool and also attending to Sainan High .",
#  'development-735Haruna',
#  'development-736Kate , his friend',
#  'development-737Snelling',
#  'development-738you',
#  'development-739Tommy Layton',
#  'development-741Hamilton',
#  'development-743Longet',
#  'development-744Jim Reeves',
#  'development-745Republicans',
#  "development-746Andrew ` Benji ' Veniamin",
#  'development-747Michael F. Cergizan',
#  'development-748r. 673 -- 642 BC',
#  'development-749Bingham',
#  'development-750Yasuko questions Mieko about her intentions for her with',
#  'development-751Madelyne',
#  'development-752Scott',
#  'development-753Dean',
#  'development-754Lady Guo as princess dowager',
#  'development-755Dr. Chakma',
#  'development-756referee Jerry Markbreit',
#  "development-757Theismann 's",
#  'development-758Influenced by actresses such as Vivien Leigh , Goldie Hawn and Kim Basinger , Jennifer',
#  'development-759Joe',
#  'development-761Martha',
#  'development-762Pedro',
#  'development-763Avril Lavigne',
#  'development-764Mary Roe Walkup',
#  'development-765The Kovenant in 1999',
#  'development-766Dudley',
#  "development-767Francy Boland 's",
#  "development-768Vysotsky 's",
#  'development-769Sten',
#  'development-770Samantha Sky Shelton -LRB- born 15 November 1978 -RRB-',
#  'development-771another old boy',
#  'development-772Jefferson Davis',
#  'development-773a genius',
#  'development-774Stevie Cameron',
#  'development-775Alderman Thomas Rigby',
#  'development-776Westall',
#  'development-777her coach',
#  'development-778Helen',
#  "development-779Austen 's",
#  'development-780Reid',
#  "development-781A neighbour of Ervine 's who was a member of the Ulster Defence Association -LRB- UDA -RRB- William Irvine",
#  'development-782Yul Brynner',
#  'development-783he',
#  'development-784Harriet Smith',
#  'development-785Moses',
#  'development-786Mrs Tapili',
#  'development-787Tish',
#  'development-788Emperor Xuanzong',
#  'development-7891901 Braun trained under the American painter William Merritt Chase -LRB- 1849-1916 -RRB-',
#  "development-790John 's",
#  'development-791Drucci',
#  'development-792Berney',
#  'development-793Cronin',
#  'development-794Alexandra',
#  'development-795Bridget',
#  'development-796John Kelling -LRB- who had already represented the Waimea electorate in Parliament -RRB-',
#  'development-797Margaret Parsons',
#  'development-798The architect of the Cathedral',
#  'development-799Vikings',
#  'development-800Stokes',
#  'development-801Haysbert',
#  'development-802Republican Senator John McCain of Arizona , who Khizr says was a hero to Humayun',
#  'development-803Hirsi Ali',
#  'development-804She',
#  'development-805Ibrahim Hooper',
#  "development-806girlfriend Jane Asher 's",
#  'development-807Evander',
#  'development-808Kylie',
#  'development-809Groom',
#  'development-810a producer for NBC',
#  'development-811writer Ken Kolb',
#  'development-812Penny Unger',
#  'development-813Andy Warhol',
#  'development-814Toskala',
#  'development-816Moose',
#  'development-817Nero Wolfe',
#  'development-818Agatha Christie',
#  'development-819Beatrice',
#  'development-820Ajay',
#  "development-821Narayanan 's",
#  'development-822Toledo',
#  'development-823Castillo',
#  'development-824Hollar',
#  'development-825Grace Metalious',
#  'development-826Lars Frederiksen',
#  "development-827Laxman 's",
#  'development-828Bourque',
#  'development-829Earl',
#  'development-830the King',
#  'development-831Isabella',
#  'development-832Lula da Silva',
#  "development-833Fahey his first paying gig -- a weeklong engagement at Boston 's Odyssey Coffeehouse in the summer of ' 65",
#  'development-834Paul Frees',
#  'development-835Kyle Busch',
#  'development-836Klunk',
#  'development-837Britney Spears',
#  'development-838Shingo',
#  'development-839Drama CD/PSP/anime',
#  'development-840Geoff Goddard',
#  'development-841Leonhard Felix Fuld',
#  'development-842Hindemith',
#  'development-843Lee',
#  'development-844Eleanor',
#  "development-845Angelica Kauffmann 's The Farewell of Abelard and H * lo",
#  'development-846Vangelis',
#  'development-847Stephenson',
#  'development-848Hawkins',
#  'development-849Dhavernas',
#  "development-850Vanessa 's",
#  'development-851General Foulois',
#  "development-852Hitler 's",
#  'development-853Landrieu in 2002',
#  'development-854the librarianship of the Bodleian whilst fellow',
#  'development-855Bonnie',
#  'development-856Sassoon , who was becoming influenced by Freudian psychoanalysis',
#  'development-857Wilson as an immediate advocate for supplying the mujahideen with Stinger missiles',
#  'development-858Melissa Auf der Maur',
#  'development-859Blue October drummer Jeremy Furstenfeld',
#  'development-860Marguerite Feitlowitz',
#  'development-861Duncan',
#  'development-862Bachee * tche',
#  'development-863Fernando Denis',
#  'development-864Dan',
#  'development-865Clay Tatum',
#  'development-866Bernard Osgood Koopman -LRB- 1900 -- August 18 , 1981 -RRB-',
#  'development-867the eldest child to Eduardo Frei Montalva and Mar * a Ruiz-Tagle Jim * nez',
#  'development-868Nicolas Perrenot de Granvelle -LRB- 1486-1550 -RRB-',
#  'development-869Livingston',
#  "development-870William `` Bill '' Rancic -LRB- / * r * nts",
#  'development-871Raveena Joseph of The Hindu',
#  'development-872Mouna Ragam',
#  'development-873Mahm',
#  'development-874H. Beam Piper : A Biography -LRB- 2008 -RRB- * * * *',
#  'development-875President Warren G. Harding',
#  'development-876Leishman',
#  'development-877Kathleen McKinnon',
#  'development-878Zeki',
#  'development-879Loew',
#  'development-880Caruso',
#  'development-881Colonel James C. Marshall',
#  'development-883Jimmy Iovine',
#  'development-884Dan Bailey',
#  'development-885Hawkey',
#  'development-886Vicki leaving',
#  'development-887Michelle',
#  'development-888Laura Elizabeth Pedersen',
#  'development-889Brigadier General Harris Otadafevwerha Deodemise Eghagha',
#  'development-890He',
#  'development-891Jackson',
#  'development-892The Stroescus',
#  'development-893Gori',
#  'development-894Maya',
#  'development-895Vishnu',
#  'development-896Derman',
#  'development-897Pirkka-Pekka Petelius as Nils Lepist *',
#  'development-898Kitty Empire of The Observer',
#  'development-900Eddie',
#  'development-901Pat Calder',
#  'development-902Dickov',
#  'development-903Emily',
#  'development-904Emily',
#  'development-905she',
#  'development-906My Girl',
#  'development-907Kabir Ali',
#  'development-908Tushar Imran',
#  'development-909Riadh Ben Aissa',
#  'development-910John Hibbett DeWitt Jr.',
#  'development-911Sergei Pakanich',
#  "development-912veteran first baseman Doug Mientkiewicz to the Boston Red Sox and Morneau became the Twins ' starting first baseman",
#  'development-913William Landay -LRB- born 1963 , in Boston , Massachusetts -RRB-',
#  'development-915Friederike',
#  'development-916Another person who debuted',
#  'development-917amicable',
#  'development-918the central character',
#  'development-919Jobson',
#  'development-920State Senator Diane Watson',
#  'development-921Slim Smith',
#  "development-922Rick Pitino as a member of the staff of the National Basketball Association 's New York Knicks",
#  'development-923Arturo',
#  'development-924Stroll',
#  "development-925infant daughter Martha Johanna Winthrop in tow , Henry 's widow",
#  'development-926Writer Howard Weinstein',
#  'development-927Cecil Calvert',
#  "development-928Aikman 's",
#  'development-929Don Pietro',
#  "development-930Ralph Ellison 's",
#  'development-931Dempsey',
#  'development-932Morgan Spurlock',
#  'development-933His father',
#  'development-934Tate',
#  'development-935the recently crowned beauty queen',
#  "development-936Bernal 's",
#  'development-937a better man than Brian',
#  "development-938marked Johnson 's",
#  'development-939Messier',
#  'development-940Connie',
#  'development-941his',
#  'development-942Sor Juana',
#  'development-943her',
#  'development-944Rashaun Allen',
#  'development-945Kristal',
#  'development-946Al-Kind *',
#  'development-947Steve Lawrence',
#  'development-948Jill Parenteau',
#  'development-949He',
#  'development-950Boxx',
#  'development-951Boxx',
#  'development-952Croatian top model Tatjana Juri * fills the host role which Tyra Banks performed in the original series .',
#  'development-953the Principal',
#  'development-954Lance',
#  'development-955The Christians of Quilon',
#  'development-956a Major Grapper',
#  'development-957Rodney Dillard',
#  'development-958Keane',
#  'development-959Harold Orton -LRB- October 23 , 1898 -- March 7 , 1975 -RRB-',
#  'development-960co-author Kai Bird',
#  'development-961Wynn',
#  'development-962she',
#  'development-963Shirley Grossman in Philadelphia , Pennsylvania',
#  'development-964Warren',
#  'development-965Merrill De Maris',
#  'development-966the couple separated',
#  'development-967the Easter Rising in 1916',
#  'development-968Gina',
#  'development-969Elizabeth Short a.k.a.',
#  'development-970Deputy Sheriff Cam Riley',
#  'development-971Candace Parker',
#  'development-972Michael Dyche',
#  'development-973Maria Ernestam',
#  'development-974Arima',
#  'development-975The puppet',
#  'development-976the daughter of Isaac Henry-Anderson and Katherine Blyth',
#  'development-977Her mother',
#  'development-978Allen Lee Peng Fei',
#  'development-979the Sorbonne',
#  'development-980Bobby Roode',
#  'development-981Corey Graves',
#  'development-982Gomi',
#  "development-983Chino 's",
#  'development-984Jennifer',
#  'development-985Denise',
#  'development-986Batman',
#  "development-987Batman , Robin , Commissioner Gordon and Chief O'Hara interrogate King Tut as Harvey",
#  'development-988Shantaram',
#  'development-989jockey Martin Garcia',
#  'development-990Cynthia Brooke',
#  'development-991Ryan Braun',
#  'development-992Kristy Johnson',
#  'development-993Henry',
#  "development-994Kyunki 's",
#  "development-995Grimes '",
#  'development-996Graf 6 -- 2 , 7 --',
#  'development-997Henry',
#  'development-998Christa Brittany Allen -LRB- born November 11 , 1991 -RRB-',
#  'development-999Maturinus',
#  'development-1000James Jimmy Kidega -LRB- born 16 August 1982 -RRB-',
#  'development-1001Liv Ullmann',
#  'development-1002Her mother',
#  'development-1003Mary Bell',
#  'development-1004the wife of former Governor of West Virginia John J. Jacob',
#  'development-1005Pacquiao',
#  'development-1006Horace',
#  'development-1007Arulnithi as Tamizh Bindu Madhavi as Malar Ashrita Shetty as Isabella Bagavathi Perumal as Ramanujam Esakki Nassar as Hippy Lahiri M S',
#  'development-1008Alice',
#  'development-1009S.J. Emmanuel',
#  'development-1010John McCarty',
#  'development-1011manager Don Givens',
#  'development-1012William de Alwis -LRB- 1842 -- 1916 -RRB-',
#  'development-1013she',
#  'development-1014Zhang Fei',
#  'development-1015Charles Spearman',
#  'development-1016Lodoli',
#  'development-1017Maya Karin',
#  'development-1018Inter-league',
#  'development-1019Kara',
#  'development-1020Carol Merrill',
#  'development-1021Moulay Muhammad',
#  "development-1022Osborne 's",
#  'development-1023She',
#  'development-1024the Frisians',
#  ...]

# %%
df = pd.DataFrame(resolved_list) 
df.to_csv('resolved_words.csv')

# %%
java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -annotators "tokenize,ssplit,pos,lemma,parse,sentiment" -port 9000 -timeout 300000000
